# %%
import numpy as np
import pandas as pd

# %%
company_df = pd.read_csv('companies.csv').set_index('Symbol')

# %%
company_df
# Out:
#                           Name                  Sector
# Symbol
# MMM                 3M Company             Industrials
# AOS            A.O. Smith Corp             Industrials
# ABT        Abbott Laboratories             Health Care
# ABBV               AbbVie Inc.             Health Care
# ACN              Accenture plc  Information Technology
# ...                        ...                     ...
# XYL                 Xylem Inc.             Industrials
# YUM            Yum! Brands Inc  Consumer Discretionary
# ZBH     Zimmer Biomet Holdings             Health Care
# ZION             Zions Bancorp              Financials
# ZTS                     Zoetis             Health Care
#
# [505 rows x 2 columns]

# %%
financial_df_1 = pd.read_csv('financials_1.csv').set_index('Symbol')

# %%
financial_df_1
# Out:
#          Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# MMM     222.89           24.31        2.332862            7.92       259.77
# AOS      60.24           27.76        1.147959            1.70        68.39
# ABT      56.27           22.51        1.908982            0.26        64.60
# ABBV    108.48           19.41        2.499560            3.29       125.86
# ACN     150.51           25.47        1.714470            5.44       162.60
# ...        ...             ...             ...             ...          ...
# ITW     156.15           23.62        1.908957            4.86       179.07
# ILMN    209.54           52.25        0.000000            4.92       248.97
# INCY     83.92         -119.89        0.000000            0.54       153.15
# IR       87.60           19.38        1.973901            5.07        97.67
# INTC     42.75           12.32        2.654867            1.98        50.85
#
# ...

# %%
financial_df_2 = pd.read_csv('financials_2.csv').set_index('Symbol')

# %%
financial_df_2
# Out:
#          Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# ICE      67.00           22.95        5.429864            2.37      76.1378
# IBM     147.59           10.67        3.899903            6.11     182.7900
# IP       56.05           15.57        3.206751            5.14      66.9400
# IPG      21.34           15.46        3.380282            1.49      25.7100
# IFF     138.00           24.17        1.934128            5.05     157.4000
# ...        ...             ...             ...             ...          ...
# XYL      70.24           30.94        1.170079            1.83      76.8100
# YUM      76.30           27.25        1.797080            4.07      86.9300
# ZBH     115.53           14.32        0.794834            9.01     133.4900
# ZION     50.71           17.73        1.480933            2.60      55.6100
# ZTS      71.51           32.80        0.682372            1.65      80.1300
#
# ...

# %%
company_df
# Out:
#                           Name                  Sector
# Symbol
# MMM                 3M Company             Industrials
# AOS            A.O. Smith Corp             Industrials
# ABT        Abbott Laboratories             Health Care
# ABBV               AbbVie Inc.             Health Care
# ACN              Accenture plc  Information Technology
# ...                        ...                     ...
# XYL                 Xylem Inc.             Industrials
# YUM            Yum! Brands Inc  Consumer Discretionary
# ZBH     Zimmer Biomet Holdings             Health Care
# ZION             Zions Bancorp              Financials
# ZTS                     Zoetis             Health Care
#
# [505 rows x 2 columns]

# %%
pd.concat([company_df, financial_df_1], axis=1)
# Out:
#                           Name                  Sector   Price  \
# Symbol
# MMM                 3M Company             Industrials  222.89
# AOS            A.O. Smith Corp             Industrials   60.24
# ABT        Abbott Laboratories             Health Care   56.27
# ABBV               AbbVie Inc.             Health Care  108.48
# ACN              Accenture plc  Information Technology  150.51
# ...                        ...                     ...     ...
# XYL                 Xylem Inc.             Industrials     NaN
# YUM            Yum! Brands Inc  Consumer Discretionary     NaN
# ZBH     Zimmer Biomet Holdings             Health Care     NaN
# ZION             Zions Bancorp              Financials     NaN
# ZTS                     Zoetis             Health Care     NaN
#
#         Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# MMM              24.31        2.332862            7.92       259.77
# ...

# %%
pd.concat([company_df, financial_df_2], axis=1)
# Out:
#                           Name                  Sector   Price  \
# Symbol
# MMM                 3M Company             Industrials     NaN
# AOS            A.O. Smith Corp             Industrials     NaN
# ABT        Abbott Laboratories             Health Care     NaN
# ABBV               AbbVie Inc.             Health Care     NaN
# ACN              Accenture plc  Information Technology     NaN
# ...                        ...                     ...     ...
# XYL                 Xylem Inc.             Industrials   70.24
# YUM            Yum! Brands Inc  Consumer Discretionary   76.30
# ZBH     Zimmer Biomet Holdings             Health Care  115.53
# ZION             Zions Bancorp              Financials   50.71
# ZTS                     Zoetis             Health Care   71.51
#
#         Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# MMM                NaN             NaN             NaN          NaN
# ...

# %%
combined_df = pd.concat([financial_df_1, financial_df_2], axis=0)

# %%
combined_df
# Out:
#          Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# MMM     222.89           24.31        2.332862            7.92       259.77
# AOS      60.24           27.76        1.147959            1.70        68.39
# ABT      56.27           22.51        1.908982            0.26        64.60
# ABBV    108.48           19.41        2.499560            3.29       125.86
# ACN     150.51           25.47        1.714470            5.44       162.60
# ...        ...             ...             ...             ...          ...
# XYL      70.24           30.94        1.170079            1.83        76.81
# YUM      76.30           27.25        1.797080            4.07        86.93
# ZBH     115.53           14.32        0.794834            9.01       133.49
# ZION     50.71           17.73        1.480933            2.60        55.61
# ZTS      71.51           32.80        0.682372            1.65        80.13
#
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 505 entries, MMM to ZTS
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Price           505 non-null    float64
#  1   Price/Earnings  503 non-null    float64
#  2   Dividend Yield  505 non-null    float64
#  3   Earnings/Share  505 non-null    float64
#  4   52 Week Low     505 non-null    float64
#  5   52 Week High    505 non-null    float64
#  6   Market Cap      505 non-null    float64
#  7   EBITDA          505 non-null    float64
#  8   Price/Sales     505 non-null    float64
#  9   Price/Book      497 non-null    float64
#  10  SEC Filings     505 non-null    object
# dtypes: float64(10), object(1)
# memory usage: 47.3+ KB

# %%
pd.concat([company_df, combined_df], axis=1)
# Out:
#                           Name                  Sector   Price  \
# Symbol
# MMM                 3M Company             Industrials  222.89
# AOS            A.O. Smith Corp             Industrials   60.24
# ABT        Abbott Laboratories             Health Care   56.27
# ABBV               AbbVie Inc.             Health Care  108.48
# ACN              Accenture plc  Information Technology  150.51
# ...                        ...                     ...     ...
# XYL                 Xylem Inc.             Industrials   70.24
# YUM            Yum! Brands Inc  Consumer Discretionary   76.30
# ZBH     Zimmer Biomet Holdings             Health Care  115.53
# ZION             Zions Bancorp              Financials   50.71
# ZTS                     Zoetis             Health Care   71.51
#
#         Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# MMM              24.31        2.332862            7.92       259.77
# ...
