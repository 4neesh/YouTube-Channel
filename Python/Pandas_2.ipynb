# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('movies.csv')

# %%
movies
# Out:
#                                   Film    Genre            Lead Studio  \
# 0                      Youth in Revolt   Comedy  The Weinstein Company
# 1   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 2                         When in Rome   Comedy                 Disney
# 3                What Happens in Vegas   Comedy                    Fox
# 4                  Water For Elephants    Drama       20th Century Fox
# ..                                 ...      ...                    ...
# 71                 Across the Universe  romance            Independent
# 72                       A Serious Man    Drama              Universal
# 73                  A Dangerous Method    Drama            Independent
# 74                          27 Dresses   Comedy                    Fox
# 75                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes %  Worldwide Gross  Year
# ...

# %%
movies.sort_values('Audience score %')
# Out:
#                                   Film      Genre            Lead Studio  \
# 1   You Will Meet a Tall Dark Stranger     Comedy            Independent
# 47                        Love Happens      Drama              Universal
# 17                  The Heartbreak Kid     Comedy              Paramount
# 2                         When in Rome     Comedy                 Disney
# 54                             Killers     Action              Lionsgate
# ..                                 ...        ...                    ...
# 38                My Week with Marilyn      Drama  The Weinstein Company
# 71                 Across the Universe    romance            Independent
# 21                             Tangled  Animation                 Disney
# 5                               WALL-E  Animation                 Disney
# 73                  A Dangerous Method      Drama            Independent
#
#     Audience score %  Profitability  Rotten Tomatoes %  Worldwide Gross  Year
# ...

# %%
movies.sort_values('Audience score %', ascending=False)
# Out:
#                                   Film      Genre            Lead Studio  \
# 73                  A Dangerous Method      Drama            Independent
# 5                               WALL-E  Animation                 Disney
# 21                             Tangled  Animation                 Disney
# 38                My Week with Marilyn      Drama  The Weinstein Company
# 71                 Across the Universe    romance            Independent
# ..                                 ...        ...                    ...
# 54                             Killers     Action              Lionsgate
# 2                         When in Rome     Comedy                 Disney
# 17                  The Heartbreak Kid     Comedy              Paramount
# 47                        Love Happens      Drama              Universal
# 1   You Will Meet a Tall Dark Stranger     Comedy            Independent
#
#     Audience score %  Profitability  Rotten Tomatoes %  Worldwide Gross  Year
# ...

# %%
movies.sort_values(['Audience score %', 'Rotten Tomatoes %'], ascending=False)
# Out:
#                                   Film      Genre            Lead Studio  \
# 5                               WALL-E  Animation                 Disney
# 73                  A Dangerous Method      Drama            Independent
# 21                             Tangled  Animation                 Disney
# 42                   Midnight in Paris    Romence                   Sony
# 38                My Week with Marilyn      Drama  The Weinstein Company
# ..                                 ...        ...                    ...
# 54                             Killers     Action              Lionsgate
# 2                         When in Rome     Comedy                 Disney
# 17                  The Heartbreak Kid     Comedy              Paramount
# 47                        Love Happens      Drama              Universal
# 1   You Will Meet a Tall Dark Stranger     Comedy            Independent
#
#     Audience score %  Profitability  Rotten Tomatoes %  Worldwide Gross  Year
# ...

# %%
movies.sort_values(['Audience score %', 'Rotten Tomatoes %'], ascending=[False, True])
# Out:
#                                   Film      Genre            Lead Studio  \
# 73                  A Dangerous Method      Drama            Independent
# 5                               WALL-E  Animation                 Disney
# 21                             Tangled  Animation                 Disney
# 71                 Across the Universe    romance            Independent
# 38                My Week with Marilyn      Drama  The Weinstein Company
# ..                                 ...        ...                    ...
# 54                             Killers     Action              Lionsgate
# 2                         When in Rome     Comedy                 Disney
# 17                  The Heartbreak Kid     Comedy              Paramount
# 47                        Love Happens      Drama              Universal
# 1   You Will Meet a Tall Dark Stranger     Comedy            Independent
#
#     Audience score %  Profitability  Rotten Tomatoes %  Worldwide Gross  Year
# ...

# %%
movies['Worldwide Gross'].max()
# Out:
# 709.82

# %%
movies['Worldwide Gross'].idxmax()
# Out:
# 13

# %%
movies.iloc[13]
# Out:
# Film                 The Twilight Saga: New Moon
# Genre                                      Drama
# Lead Studio                               Summit
# Audience score %                              78
# Profitability                            14.1964
# Rotten Tomatoes %                             27
# Worldwide Gross                           709.82
# Year                                        2009
# Name: 13, dtype: object

# %%
movies.iloc[movies['Worldwide Gross'].idxmax()]
# Out:
# Film                 The Twilight Saga: New Moon
# Genre                                      Drama
# Lead Studio                               Summit
# Audience score %                              78
# Profitability                            14.1964
# Rotten Tomatoes %                             27
# Worldwide Gross                           709.82
# Year                                        2009
# Name: 13, dtype: object

# %%
movies['Worldwide Gross'].min()
# Out:
# 0.03

# %%
movies['Worldwide Gross'].idxmin()
# Out:
# 7

# %%
movies.iloc[7]
# Out:
# Film                 Waiting For Forever
# Genre                            Romance
# Lead Studio                  Independent
# Audience score %                      53
# Profitability                      0.005
# Rotten Tomatoes %                      6
# Worldwide Gross                     0.03
# Year                                2011
# Name: 7, dtype: object

# %%
movies.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 movies.corr()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
movies.corr(numeric_only=True)
# Out:
#                    Audience score %  Profitability  Rotten Tomatoes %  \
# Audience score %           1.000000       0.068606           0.606906
# Profitability              0.068606       1.000000           0.045739
# Rotten Tomatoes %          0.606906       0.045739           1.000000
# Worldwide Gross            0.389898       0.167330           0.027388
# Year                      -0.226329      -0.186841          -0.086700
#
#                    Worldwide Gross      Year
# Audience score %          0.389898 -0.226329
# Profitability             0.167330 -0.186841
# Rotten Tomatoes %         0.027388 -0.086700
# Worldwide Gross           1.000000 -0.139275
# Year                     -0.139275  1.000000

# %%
movies
# Out:
#                                   Film    Genre            Lead Studio  \
# 0                      Youth in Revolt   Comedy  The Weinstein Company
# 1   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 2                         When in Rome   Comedy                 Disney
# 3                What Happens in Vegas   Comedy                    Fox
# 4                  Water For Elephants    Drama       20th Century Fox
# ..                                 ...      ...                    ...
# 71                 Across the Universe  romance            Independent
# 72                       A Serious Man    Drama              Universal
# 73                  A Dangerous Method    Drama            Independent
# 74                          27 Dresses   Comedy                    Fox
# 75                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes %  Worldwide Gross  Year
# ...

# %%
movies['Genre'].value_counts()
# Out:
# Genre
# Comedy       41
# Drama        13
# Romance      12
# Animation     4
# Fantasy       1
# Romence       1
# Comdy         1
# Action        1
# romance       1
# comedy        1
# Name: count, dtype: int64

# %%
movies['Genre'].unique()
# Out:
# array(['Comedy', 'Drama', 'Animation', 'Romance', 'Fantasy', 'Romence',
#        'Comdy', 'Action', 'romance', 'comedy'], dtype=object)

# %%
movies['Genre'].nunique()
# Out:
# 10

# %%
movies['Genre'].replace('Comdy', 'Comedy')
# Out:
# 0      Comedy
# 1      Comedy
# 2      Comedy
# 3      Comedy
# 4       Drama
#        ...
# 71    romance
# 72      Drama
# 73      Drama
# 74     Comedy
# 75     comedy
# Name: Genre, Length: 76, dtype: object

# %%
movies
# Out:
#                                   Film    Genre            Lead Studio  \
# 0                      Youth in Revolt   Comedy  The Weinstein Company
# 1   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 2                         When in Rome   Comedy                 Disney
# 3                What Happens in Vegas   Comedy                    Fox
# 4                  Water For Elephants    Drama       20th Century Fox
# ..                                 ...      ...                    ...
# 71                 Across the Universe  romance            Independent
# 72                       A Serious Man    Drama              Universal
# 73                  A Dangerous Method    Drama            Independent
# 74                          27 Dresses   Comedy                    Fox
# 75                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes %  Worldwide Gross  Year
# ...

# %%
movies['Genre'] = movies['Genre'].replace(['Comdy', 'comedy', 'romance', 'Romence'], ['Comedy', 'Comedy', 'Romance', 'Romance'])

# %%
movies['Genre'].value_counts()
# Out:
# Genre
# Comedy       43
# Romance      14
# Drama        13
# Animation     4
# Fantasy       1
# Action        1
# Name: count, dtype: int64

# %%
replace_dict = {'Comdy':'Comedy', 'romance':'Romance', 'comedy':'Comedy', 'Romence':'Romance'}

# %%
movies['Genre'].replace(replace_dict)
# Out:
# 0      Comedy
# 1      Comedy
# 2      Comedy
# 3      Comedy
# 4       Drama
#        ...
# 71    Romance
# 72      Drama
# 73      Drama
# 74     Comedy
# 75     Comedy
# Name: Genre, Length: 76, dtype: object

# %%
movies['Audience score %'].between(40,50)
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
#       ...
# 71    False
# 72    False
# 73    False
# 74    False
# 75    False
# Name: Audience score %, Length: 76, dtype: bool

# %%
movies[movies['Audience score %'].between(40,50)]
# Out:
#                                    Film    Genre       Lead Studio  \
# 2                          When in Rome   Comedy            Disney
# 9   Tyler Perry's Why Did I get Married  Romance       Independent
# 16               The Invention of Lying   Comedy      Warner Bros.
# 17                   The Heartbreak Kid   Comedy         Paramount
# 20                     The Back-up Plan   Comedy               CBS
# 22                   Something Borrowed  Romance       Independent
# 24                 Sex and the City Two   Comedy      Warner Bros.
# 25                   Sex and the City 2   Comedy      Warner Bros.
# 31                   Over Her Dead Body   Comedy          New Line
# 32                   Our Family Wedding   Comedy       Independent
# 37                       New Year's Eve  Romance      Warner Bros.
# 40                          Monte Carlo  Romance  20th Century Fox
# 47                         Love Happens    Drama         Universal
# ...

# %%
movies.nlargest(5, 'Profitability')
# Out:
#                                   Film    Genre  Lead Studio  \
# 67                           Fireproof    Drama  Independent
# 59  High School Musical 3: Senior Year   Comedy       Disney
# 13         The Twilight Saga: New Moon    Drama       Summit
# 6                             Waitress  Romance  Independent
# 11                            Twilight  Romance       Summit
#
#     Audience score %  Profitability  Rotten Tomatoes %  Worldwide Gross  Year
# 67                51      66.934000                 40            33.47  2008
# 59                76      22.913136                 65           252.04  2008
# 13                78      14.196400                 27           709.82  2009
# 6                 67      11.089742                 89            22.18  2007
# 11                82      10.180027                 49           376.66  2008

# %%
movies.nsmallest(10, 'Audience score %')
# Out:
#                                    Film    Genre   Lead Studio  \
# 1    You Will Meet a Tall Dark Stranger   Comedy   Independent
# 47                         Love Happens    Drama     Universal
# 17                   The Heartbreak Kid   Comedy     Paramount
# 2                          When in Rome   Comedy        Disney
# 54                              Killers   Action     Lionsgate
# 9   Tyler Perry's Why Did I get Married  Romance   Independent
# 16               The Invention of Lying   Comedy  Warner Bros.
# 20                     The Back-up Plan   Comedy           CBS
# 31                   Over Her Dead Body   Comedy      New Line
# 65           Ghosts of Girlfriends Past   Comedy  Warner Bros.
#
#     Audience score %  Profitability  Rotten Tomatoes %  Worldwide Gross  Year
# 1                 35       1.211818                 43            26.66  2010
# 47                40       2.004444                 18            36.08  2009
# ...

# %%
movies.sample(5)
# Out:
#                                   Film   Genre   Lead Studio  \
# 51                   Letters to Juliet  Comedy        Summit
# 16              The Invention of Lying  Comedy  Warner Bros.
# 2                         When in Rome  Comedy        Disney
# 36  Nick and Norah's Infinite Playlist  Comedy          Sony
# 69                           Dear John   Drama          Sony
#
#     Audience score %  Profitability  Rotten Tomatoes %  Worldwide Gross  Year
# 51                62       2.639333                 40            79.18  2010
# 16                47       1.751351                 56            32.40  2009
# 2                 44       0.000000                 15            43.04  2010
# 36                67       3.352729                 73            33.53  2008
# 69                66       4.598800                 29           114.97  2010

# %%
movies.sample(frac=0.04)
# Out:
#                       Film   Genre Lead Studio  Audience score %  \
# 18             The Duchess   Drama   Paramount                68
# 23  She's Out of My League  Comedy   Paramount                60
# 52               Leap Year  Comedy   Universal                49
#
#     Profitability  Rotten Tomatoes %  Worldwide Gross  Year
# 18       3.207850                 60            43.31  2008
# 23       2.440500                 57            48.81  2010
# 52       1.715263                 21            32.59  2010
